# %%
import numpy as np
import gym
import torch
import torch.nn as nn
import torch.nn.functional as F
from collections import namedtuple

# %%
GAMMA = 0.9
LEARNING_RATE = 0.001

Transition = namedtuple('Transition', ('state', 'action', 'next_state', 'reward', 'done'))

# %%
class QLearningAgent:
    def __init__(self, num_states, num_actions):
        self.num_states = num_states
        self.num_actions = num_actions
        
        self.epsilon = 1.0
        self.min_epsilon = 0.01
        self.epsilon_decay = 0.5
        self.action_list = np.arange(num_actions)
        
        self.model = self._get_model()
        self.optimizer = torch.optim.Adam(self.model.parameters(), lr=LEARNING_RATE)
        
    def get_action(self, state, episode=None, train=True):
        if train:
            if self.epsilon <= np.random.uniform(0, 1):
                with torch.no_grad():
                    state = torch.FloatTensor(state).view(1, -1)
                    action = self.model(state).max(1)[1].item()
            else:
                action = np.random.choice(self.action_list)
        else:
            with torch.no_grad():
                state = torch.FloatTensor(state).view(1, -1)
                action = self.model(state).max(1)[1].item()
            
        return action
    
    def train(self, episode, state, action, next_state, reward, done):
        next_action = self.get_action(next_state, episode)
        
        state = torch.FloatTensor(state).view(-1, self.num_states)
        action = torch.LongTensor([action]).view(-1, 1)
        reward = torch.FloatTensor([reward]).view(-1, 1)
        next_state = torch.FloatTensor(next_state).view(-1, self.num_states)
        done = torch.ByteTensor([done]).view(-1, 1)
        next_action = torch.LongTensor([next_action]).view(-1, 1)
        
        state_action_value = self.model(state).gather(1, action)
#         next_state_action_value = self.model(next_state).gather(1, next_action)
        next_state_action_value = self.model(next_state).max(1)[0].view(-1, 1)
        
        td_target = reward + GAMMA * (1 - done) * next_state_action_value
        
        loss = F.smooth_l1_loss(state_action_value, td_target)
#         loss = F.mse_loss(state_action_value, td_target)
        
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
        
        return loss.item()
    
    def decay_epsilon(self, episode):
        if self.epsilon > self.min_epsilon:
            self.epsilon *= self.epsilon_decay    
        
    def _get_model(self):
        model = nn.Sequential()
        model.add_module('fc1', nn.Linear(self.num_states, 32))
        model.add_module('relu1', nn.ReLU())
        model.add_module('fc2', nn.Linear(32, 32))
        model.add_module('relu2', nn.ReLU())
        model.add_module('fc3', nn.Linear(32, self.num_actions))
        return model

# %%
env = gym.make('CartPole-v0')

# %%
agent = QLearningAgent(4, 2)

# %%
N_EPOCH = 500

# %%
for episode in range(N_EPOCH):
    done = False
    state = env.reset()
    step = 0
    while not done:
        action = agent.get_action(state, episode)
        next_state, reward, done, _ = env.step(action)
        if done:
            if step < 195:
                reward = -1.0
            else:
                reward = 1.0
        else:
            reward = 0.0
            
        agent.train(episode, state, action, next_state, reward, done)
        state = next_state
        step += 1
    agent.decay_epsilon(episode)
    print("Episdoe {} Step {}".format(episode, step))
# Out:
# Episdoe 0 Step 25
# Episdoe 1 Step 12
# Episdoe 2 Step 9
# Episdoe 3 Step 10
# Episdoe 4 Step 9
# Episdoe 5 Step 14
# Episdoe 6 Step 13
# Episdoe 7 Step 13
# Episdoe 8 Step 17
# Episdoe 9 Step 12
# Episdoe 10 Step 13
# Episdoe 11 Step 30
# Episdoe 12 Step 9
# Episdoe 13 Step 33
# Episdoe 14 Step 28
# Episdoe 15 Step 34
# Episdoe 16 Step 19
# Episdoe 17 Step 19
# Episdoe 18 Step 38
# Episdoe 19 Step 18
# Episdoe 20 Step 21
# Episdoe 21 Step 55
# Episdoe 22 Step 35
# Episdoe 23 Step 34
# Episdoe 24 Step 20
# Episdoe 25 Step 27
# Episdoe 26 Step 28
# Episdoe 27 Step 19
# Episdoe 28 Step 73
# Episdoe 29 Step 16
# Episdoe 30 Step 27
# Episdoe 31 Step 17
# Episdoe 32 Step 17
# Episdoe 33 Step 12
# Episdoe 34 Step 11
# Episdoe 35 Step 24
# Episdoe 36 Step 31
# Episdoe 37 Step 20
# Episdoe 38 Step 45
# Episdoe 39 Step 81
# Episdoe 40 Step 26
# Episdoe 41 Step 16
# Episdoe 42 Step 50
# Episdoe 43 Step 28
# Episdoe 44 Step 52
# Episdoe 45 Step 25
# Episdoe 46 Step 65
# Episdoe 47 Step 21
# Episdoe 48 Step 37
# Episdoe 49 Step 34
# Episdoe 50 Step 41
# Episdoe 51 Step 61
# Episdoe 52 Step 18
# Episdoe 53 Step 50
# Episdoe 54 Step 43
# Episdoe 55 Step 17
# Episdoe 56 Step 70
# Episdoe 57 Step 69
# Episdoe 58 Step 73
# Episdoe 59 Step 167
# Episdoe 60 Step 15
# Episdoe 61 Step 22
# Episdoe 62 Step 85
# Episdoe 63 Step 88
# Episdoe 64 Step 42
# Episdoe 65 Step 35
# Episdoe 66 Step 83
# Episdoe 67 Step 12
# Episdoe 68 Step 13
# Episdoe 69 Step 15
# Episdoe 70 Step 61
# Episdoe 71 Step 33
# Episdoe 72 Step 105
# Episdoe 73 Step 15
# Episdoe 74 Step 10
# Episdoe 75 Step 10
# Episdoe 76 Step 11
# Episdoe 77 Step 10
# Episdoe 78 Step 14
# Episdoe 79 Step 27
# Episdoe 80 Step 159
# Episdoe 81 Step 75
# Episdoe 82 Step 116
# Episdoe 83 Step 11
# Episdoe 84 Step 47
# Episdoe 85 Step 56
# Episdoe 86 Step 27
# Episdoe 87 Step 42
# Episdoe 88 Step 92
# Episdoe 89 Step 200
# Episdoe 90 Step 44
# Episdoe 91 Step 25
# Episdoe 92 Step 21
# Episdoe 93 Step 89
# Episdoe 94 Step 200
# Episdoe 95 Step 134
# Episdoe 96 Step 16
# Episdoe 97 Step 17
# Episdoe 98 Step 26
# Episdoe 99 Step 200
# Episdoe 100 Step 85
# Episdoe 101 Step 200
# Episdoe 102 Step 152
# Episdoe 103 Step 17
# Episdoe 104 Step 15
# Episdoe 105 Step 14
# Episdoe 106 Step 53
# Episdoe 107 Step 86
# Episdoe 108 Step 200
# Episdoe 109 Step 200
# Episdoe 110 Step 200
# Episdoe 111 Step 148
# Episdoe 112 Step 10
# Episdoe 113 Step 10
# Episdoe 114 Step 9
# Episdoe 115 Step 11
# Episdoe 116 Step 10
# Episdoe 117 Step 11
# Episdoe 118 Step 9
# Episdoe 119 Step 9
# Episdoe 120 Step 9
# Episdoe 121 Step 9
# Episdoe 122 Step 9
# Episdoe 123 Step 10
# Episdoe 124 Step 10
# Episdoe 125 Step 10
# Episdoe 126 Step 9
# Episdoe 127 Step 10
# Episdoe 128 Step 9
# Episdoe 129 Step 10
# Episdoe 130 Step 9
# Episdoe 131 Step 10
# Episdoe 132 Step 9
# Episdoe 133 Step 11
# Episdoe 134 Step 10
# Episdoe 135 Step 10
# Episdoe 136 Step 9
# Episdoe 137 Step 10
# Episdoe 138 Step 9
# Episdoe 139 Step 10
# Episdoe 140 Step 9
# Episdoe 141 Step 10
# Episdoe 142 Step 9
# Episdoe 143 Step 10
# Episdoe 144 Step 8
# Episdoe 145 Step 10
# Episdoe 146 Step 9
# Episdoe 147 Step 10
# Episdoe 148 Step 8
# Episdoe 149 Step 10
# Episdoe 150 Step 8
# Episdoe 151 Step 9
# Episdoe 152 Step 9
# Episdoe 153 Step 10
# Episdoe 154 Step 9
# Episdoe 155 Step 10
# Episdoe 156 Step 9
# Episdoe 157 Step 10
# Episdoe 158 Step 8
# Episdoe 159 Step 10
# Episdoe 160 Step 9
# Episdoe 161 Step 9
# Episdoe 162 Step 8
# Episdoe 163 Step 10
# Episdoe 164 Step 10
# Episdoe 165 Step 10
# Episdoe 166 Step 9
# Episdoe 167 Step 10
# Episdoe 168 Step 10
# Episdoe 169 Step 9
# Episdoe 170 Step 10
# Episdoe 171 Step 8
# Episdoe 172 Step 9
# Episdoe 173 Step 10
# Episdoe 174 Step 8
# Episdoe 175 Step 9
# Episdoe 176 Step 11
# Episdoe 177 Step 9
# Episdoe 178 Step 9
# Episdoe 179 Step 10
# Episdoe 180 Step 9
# Episdoe 181 Step 10
# Episdoe 182 Step 8
# Episdoe 183 Step 8
# Episdoe 184 Step 149
# Episdoe 185 Step 122
# Episdoe 186 Step 114
# Episdoe 187 Step 200
# Episdoe 188 Step 28
# Episdoe 189 Step 26
# Episdoe 190 Step 200
# Episdoe 191 Step 132
# Episdoe 192 Step 200
# Episdoe 193 Step 200
# Episdoe 194 Step 200
# Episdoe 195 Step 132
# Episdoe 196 Step 88
# Episdoe 197 Step 40
# Episdoe 198 Step 84
# Episdoe 199 Step 148
# Episdoe 200 Step 33
# Episdoe 201 Step 108
# Episdoe 202 Step 71
# Episdoe 203 Step 200
# Episdoe 204 Step 170
# Episdoe 205 Step 143
# Episdoe 206 Step 200
# Episdoe 207 Step 199
# Episdoe 208 Step 15
# Episdoe 209 Step 15
# Episdoe 210 Step 13
# Episdoe 211 Step 127
# Episdoe 212 Step 200
# Episdoe 213 Step 116
# Episdoe 214 Step 9
# Episdoe 215 Step 8
# Episdoe 216 Step 9
# Episdoe 217 Step 9
# Episdoe 218 Step 10
# Episdoe 219 Step 9
# Episdoe 220 Step 9
# Episdoe 221 Step 9
# Episdoe 222 Step 10
# Episdoe 223 Step 10
# Episdoe 224 Step 9
# Episdoe 225 Step 10
# Episdoe 226 Step 10
# Episdoe 227 Step 10
# Episdoe 228 Step 8
# Episdoe 229 Step 9
# Episdoe 230 Step 9
# Episdoe 231 Step 10
# Episdoe 232 Step 9
# Episdoe 233 Step 9
# Episdoe 234 Step 9
# Episdoe 235 Step 10
# Episdoe 236 Step 10
# Episdoe 237 Step 10
# Episdoe 238 Step 11
# Episdoe 239 Step 10
# Episdoe 240 Step 9
# Episdoe 241 Step 9
# Episdoe 242 Step 8
# Episdoe 243 Step 9
# Episdoe 244 Step 9
# Episdoe 245 Step 9
# Episdoe 246 Step 9
# Episdoe 247 Step 8
# Episdoe 248 Step 8
# Episdoe 249 Step 9
# Episdoe 250 Step 10
# Episdoe 251 Step 9
# Episdoe 252 Step 9
# Episdoe 253 Step 9
# Episdoe 254 Step 10
# Episdoe 255 Step 11
# Episdoe 256 Step 10
# Episdoe 257 Step 10
# Episdoe 258 Step 9
# Episdoe 259 Step 9
# Episdoe 260 Step 9
# Episdoe 261 Step 8
# Episdoe 262 Step 11
# Episdoe 263 Step 9
# Episdoe 264 Step 10
# Episdoe 265 Step 149
# Episdoe 266 Step 17
# Episdoe 267 Step 94
# Episdoe 268 Step 200
# Episdoe 269 Step 200
# Episdoe 270 Step 175
# Episdoe 271 Step 200
# Episdoe 272 Step 200
# Episdoe 273 Step 103
# Episdoe 274 Step 140
# Episdoe 275 Step 133
# Episdoe 276 Step 171
# Episdoe 277 Step 162
# Episdoe 278 Step 200
# Episdoe 279 Step 200
# Episdoe 280 Step 200
# Episdoe 281 Step 200
# Episdoe 282 Step 200
# Episdoe 283 Step 200
# Episdoe 284 Step 200
# Episdoe 285 Step 14
# Episdoe 286 Step 12
# Episdoe 287 Step 56
# Episdoe 288 Step 120
# Episdoe 289 Step 175
# Episdoe 290 Step 14
# Episdoe 291 Step 20
# Episdoe 292 Step 200
# Episdoe 293 Step 200
# Episdoe 294 Step 200
# Episdoe 295 Step 200
# Episdoe 296 Step 200
# Episdoe 297 Step 200
# Episdoe 298 Step 200
# Episdoe 299 Step 200
# Episdoe 300 Step 200
# Episdoe 301 Step 200
# Episdoe 302 Step 200
# Episdoe 303 Step 200
# Episdoe 304 Step 200
# Episdoe 305 Step 200
# Episdoe 306 Step 200
# Episdoe 307 Step 200
# Episdoe 308 Step 200
# Episdoe 309 Step 62
# Episdoe 310 Step 200
# Episdoe 311 Step 200
# Episdoe 312 Step 200
# Episdoe 313 Step 18
# Episdoe 314 Step 17
# Episdoe 315 Step 200
# Episdoe 316 Step 200
# Episdoe 317 Step 200
# Episdoe 318 Step 200
# Episdoe 319 Step 200
# Episdoe 320 Step 200
# Episdoe 321 Step 200
# Episdoe 322 Step 200
# Episdoe 323 Step 200
# Episdoe 324 Step 200
# Episdoe 325 Step 200
# Episdoe 326 Step 200
# Episdoe 327 Step 200
# Episdoe 328 Step 200
# Episdoe 329 Step 200
# Episdoe 330 Step 200
# Episdoe 331 Step 200
# Episdoe 332 Step 200
# Episdoe 333 Step 200
# Episdoe 334 Step 200
# Episdoe 335 Step 200
# Episdoe 336 Step 14
# Episdoe 337 Step 9
# Episdoe 338 Step 8
# Episdoe 339 Step 8
# Episdoe 340 Step 11
# Episdoe 341 Step 200
# Episdoe 342 Step 145
# Episdoe 343 Step 15
# Episdoe 344 Step 12
# Episdoe 345 Step 200
# Episdoe 346 Step 200
# Episdoe 347 Step 200
# Episdoe 348 Step 200
# Episdoe 349 Step 200
# Episdoe 350 Step 175
# Episdoe 351 Step 200
# Episdoe 352 Step 200
# Episdoe 353 Step 200
# Episdoe 354 Step 200
# Episdoe 355 Step 200
# Episdoe 356 Step 200
# Episdoe 357 Step 200
# Episdoe 358 Step 200
# Episdoe 359 Step 200
# Episdoe 360 Step 200
# Episdoe 361 Step 200
# Episdoe 362 Step 200
# Episdoe 363 Step 200
# Episdoe 364 Step 200
# Episdoe 365 Step 200
# Episdoe 366 Step 200
# Episdoe 367 Step 200
# Episdoe 368 Step 200
# Episdoe 369 Step 200
# Episdoe 370 Step 200
# Episdoe 371 Step 200
# Episdoe 372 Step 200
# Episdoe 373 Step 200
# Episdoe 374 Step 200
# Episdoe 375 Step 200
# Episdoe 376 Step 200
# Episdoe 377 Step 200
# Episdoe 378 Step 200
# Episdoe 379 Step 200
# Episdoe 380 Step 200
# Episdoe 381 Step 200
# Episdoe 382 Step 200
# Episdoe 383 Step 200
# Episdoe 384 Step 200
# Episdoe 385 Step 200
# Episdoe 386 Step 200
# Episdoe 387 Step 200
# Episdoe 388 Step 200
# Episdoe 389 Step 200
# Episdoe 390 Step 200
# Episdoe 391 Step 200
# Episdoe 392 Step 200
# Episdoe 393 Step 200
# Episdoe 394 Step 200
# Episdoe 395 Step 200
# Episdoe 396 Step 200
# Episdoe 397 Step 200
# Episdoe 398 Step 200
# Episdoe 399 Step 200
# Episdoe 400 Step 200
# Episdoe 401 Step 200
# Episdoe 402 Step 200
# Episdoe 403 Step 200
# Episdoe 404 Step 200
# Episdoe 405 Step 200
# Episdoe 406 Step 200
# Episdoe 407 Step 12
# Episdoe 408 Step 10
# Episdoe 409 Step 10
# Episdoe 410 Step 10
# Episdoe 411 Step 10
# Episdoe 412 Step 9
# Episdoe 413 Step 9
# Episdoe 414 Step 10
# Episdoe 415 Step 10
# Episdoe 416 Step 9
# Episdoe 417 Step 11
# Episdoe 418 Step 10
# Episdoe 419 Step 200
# Episdoe 420 Step 200
# Episdoe 421 Step 200
# Episdoe 422 Step 200
# Episdoe 423 Step 200
# Episdoe 424 Step 191
# Episdoe 425 Step 200
# Episdoe 426 Step 200
# Episdoe 427 Step 200
# Episdoe 428 Step 160
# Episdoe 429 Step 200
# Episdoe 430 Step 200
# Episdoe 431 Step 177
# Episdoe 432 Step 194
# Episdoe 433 Step 200
# Episdoe 434 Step 200
# Episdoe 435 Step 193
# Episdoe 436 Step 194
# Episdoe 437 Step 200
# Episdoe 438 Step 200
# Episdoe 439 Step 200
# Episdoe 440 Step 200
# Episdoe 441 Step 10
# Episdoe 442 Step 10
# Episdoe 443 Step 9
# Episdoe 444 Step 8
# Episdoe 445 Step 10
# Episdoe 446 Step 8
# Episdoe 447 Step 9
# Episdoe 448 Step 10
# Episdoe 449 Step 9
# Episdoe 450 Step 10
# Episdoe 451 Step 9
# Episdoe 452 Step 11
# Episdoe 453 Step 10
# Episdoe 454 Step 13
# Episdoe 455 Step 10
# Episdoe 456 Step 11
# Episdoe 457 Step 10
# Episdoe 458 Step 10
# Episdoe 459 Step 11
# Episdoe 460 Step 11
# Episdoe 461 Step 12
# Episdoe 462 Step 200
# Episdoe 463 Step 200
# Episdoe 464 Step 200
# Episdoe 465 Step 189
# Episdoe 466 Step 169
# Episdoe 467 Step 10
# Episdoe 468 Step 10
# Episdoe 469 Step 19
# Episdoe 470 Step 200
# Episdoe 471 Step 200
# Episdoe 472 Step 200
# Episdoe 473 Step 200
# Episdoe 474 Step 200
# Episdoe 475 Step 200
# Episdoe 476 Step 169
# Episdoe 477 Step 149
# Episdoe 478 Step 193
# Episdoe 479 Step 162
# Episdoe 480 Step 200
# Episdoe 481 Step 200
# Episdoe 482 Step 200
# Episdoe 483 Step 141
# Episdoe 484 Step 149
# Episdoe 485 Step 192
# Episdoe 486 Step 200
# Episdoe 487 Step 180
# Episdoe 488 Step 182
# Episdoe 489 Step 200
# Episdoe 490 Step 200
# Episdoe 491 Step 173
# Episdoe 492 Step 91
# Episdoe 493 Step 15
# Episdoe 494 Step 14
# Episdoe 495 Step 200
# Episdoe 496 Step 200
# Episdoe 497 Step 200
# Episdoe 498 Step 200
# Episdoe 499 Step 200
