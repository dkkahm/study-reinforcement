# %%
import numpy as np
import gym
import torch
import torch.nn as nn
import torch.nn.functional as F
from collections import namedtuple

# %%
CRITIC_LEARNING_RATE = 0.001
ACTOR_LEARNING_RATE = 0.0001
GAMMA = 0.9

# %%
class A2CAgent:
    def __init__(self, num_states, num_actions):
        self.num_states = num_states
        self.num_actions = num_actions
        self.action_list = np.arange(num_actions)
        
        self.critic_model = self._get_critic_model()
        self.critic_optimizer = torch.optim.Adam(self.critic_model.parameters(), lr=CRITIC_LEARNING_RATE)
        
        self.actor_model = self._get_actor_model()
        self.actor_optimizer = torch.optim.Adam(self.actor_model.parameters(), lr=ACTOR_LEARNING_RATE)

    def get_action(self, state, train=True, episode = None):
        state = torch.FloatTensor(state).view(1, -1)
        policy = self.actor_model(state)
        return np.random.choice(self.action_list, p=policy.detach().numpy().ravel())
    
    def train(self, state, action, next_state, reward, done, episode=None):
        state = torch.FloatTensor(state).view(1, -1)
        action = torch.LongTensor([action]).view(1, -1)
        next_state = torch.FloatTensor(next_state).view(1, -1)
        reward = torch.FloatTensor([reward]).view(1, -1)
        done = torch.ByteTensor([done]).view(1, -1)
        
        state_value = self.critic_model(state)
        next_state_value = self.critic_model(next_state)
        critic_target = reward + GAMMA * (1 - done) * next_state_value
        
        critic_loss = F.smooth_l1_loss(state_value, critic_target)
        self.critic_optimizer.zero_grad()
        critic_loss.backward()
        self.critic_optimizer.step()
        
        advantage_value = (critic_target - state_value).detach()
        
        policy = self.actor_model(state)
        selected_action_prob = policy.gather(1, action)
        log_selected_action_prob = torch.log(selected_action_prob)
        
        actor_loss = -(log_selected_action_prob * advantage_value)
        self.actor_optimizer.zero_grad()
        actor_loss.backward()
        self.actor_optimizer.step()
        
        return actor_loss.item()
    
    def _get_critic_model(self):
        model = nn.Sequential()
        model.add_module('fc1', nn.Linear(self.num_states, 32))
        model.add_module('relu1', nn.ReLU())
        model.add_module('fc2', nn.Linear(32, 32))
        model.add_module('relu2', nn.ReLU())
        model.add_module('fc3', nn.Linear(32, 1))
        return model     
    
    def _get_actor_model(self):
        model = nn.Sequential()
        model.add_module('fc1', nn.Linear(self.num_states, 32))
        model.add_module('relu1', nn.ReLU())
        model.add_module('fc2', nn.Linear(32, 32))
        model.add_module('relu2', nn.ReLU())
        model.add_module('fc3', nn.Linear(32, self.num_actions))
        model.add_module('softmax1', nn.Softmax(dim=1))
        return model

# %%
env = gym.make('CartPole-v0')

# %%
agent = A2CAgent(env.observation_space.shape[0], env.action_space.n)

# %%
N_EPOCH = 500

# %%
for episode in range(N_EPOCH):
    done = False
    state = env.reset()
    step = 0
    while not done:
        action = agent.get_action(state)
        next_state, reward, done, _ = env.step(action)
        if done:
            if step < 195:
                reward = -1.0
            else:
                reward = 1.0
        else:
            reward = 0.0
            
        agent.train(state, action, next_state, reward, done)
        
        state = next_state
        step += 1
        
    print("Episode {} Step {}".format(episode, step))
# Out:
# Episode 0 Step 14
# Episode 1 Step 64
# Episode 2 Step 22
# Episode 3 Step 26
# Episode 4 Step 24
# Episode 5 Step 18
# Episode 6 Step 22
# Episode 7 Step 32
# Episode 8 Step 31
# Episode 9 Step 16
# Episode 10 Step 29
# Episode 11 Step 46
# Episode 257 Step 106
# Episode 258 Step 159
# Episode 259 Step 105
# Episode 260 Step 81
# Episode 261 Step 166
# Episode 262 Step 125
# Episode 263 Step 75
# Episode 264 Step 85
# Episode 265 Step 127
# Episode 266 Step 121
# Episode 267 Step 98
# Episode 268 Step 179
# Episode 269 Step 128
# Episode 270 Step 113
# Episode 271 Step 192
# Episode 272 Step 161
# Episode 273 Step 136
# Episode 274 Step 200
# Episode 275 Step 145
# Episode 276 Step 111
# Episode 277 Step 99
# Episode 278 Step 133
# Episode 279 Step 155
# Episode 280 Step 96
# Episode 281 Step 114
# Episode 282 Step 179
# Episode 283 Step 200
# Episode 284 Step 75
# Episode 285 Step 106
# Episode 286 Step 64
# Episode 287 Step 141
# Episode 288 Step 160
# Episode 289 Step 128
# Episode 290 Step 200
# Episode 291 Step 192
# Episode 292 Step 200
# Episode 293 Step 156
# Episode 294 Step 141
# Episode 295 Step 51
# Episode 296 Step 88
# Episode 297 Step 40
# Episode 298 Step 200
# Episode 299 Step 156
# Episode 300 Step 157
# Episode 301 Step 125
# Episode 302 Step 200
# Episode 303 Step 200
# Episode 304 Step 200
# Episode 305 Step 84
# Episode 306 Step 120
# Episode 307 Step 103
# Episode 308 Step 174
# Episode 309 Step 144
# Episode 310 Step 200
# Episode 311 Step 73
# Episode 312 Step 200
# Episode 313 Step 158
# Episode 314 Step 133
# Episode 315 Step 200
# Episode 316 Step 137
# Episode 317 Step 200
# Episode 318 Step 200
# Episode 319 Step 200
# Episode 320 Step 200
# Episode 321 Step 193
# Episode 322 Step 196
# Episode 323 Step 200
# Episode 324 Step 112
# Episode 325 Step 153
# Episode 326 Step 111
# Episode 327 Step 200
# Episode 328 Step 200
# Episode 329 Step 125
# Episode 330 Step 160
# Episode 331 Step 200
# Episode 332 Step 200
# Episode 333 Step 103
# Episode 334 Step 90
# Episode 335 Step 166
# Episode 336 Step 110
# Episode 337 Step 126
# Episode 338 Step 200
# Episode 339 Step 156
# Episode 340 Step 200
# Episode 341 Step 120
# Episode 342 Step 149
# Episode 343 Step 200
# Episode 344 Step 190
# Episode 345 Step 200
# Episode 346 Step 200
# Episode 347 Step 105
# Episode 348 Step 168
# Episode 349 Step 200
# Episode 350 Step 145
# Episode 351 Step 146
# Episode 352 Step 160
# Episode 353 Step 151
# Episode 354 Step 200
# Episode 355 Step 200
# Episode 356 Step 200
# Episode 357 Step 131
# Episode 358 Step 143
# Episode 359 Step 129
# Episode 360 Step 200
# Episode 361 Step 200
# Episode 362 Step 200
# Episode 363 Step 200
# Episode 364 Step 146
# Episode 365 Step 200
# Episode 366 Step 186
# Episode 367 Step 111
# Episode 368 Step 169
# Episode 369 Step 200
# Episode 370 Step 161
# Episode 371 Step 200
# Episode 372 Step 200
# Episode 373 Step 165
# Episode 374 Step 200
# Episode 375 Step 82
# Episode 376 Step 196
# Episode 377 Step 84
# Episode 378 Step 52
# Episode 379 Step 83
